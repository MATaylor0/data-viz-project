# %%
import pandas as pd
import datetime as dt

# %%
# data = pd.read_stata('c:/users/home/downloads/country_hsproduct4digit_year.dta')

# %%
# data

# %%
# data.columns

# %%
# df = pd.read_csv("c:/users/home/downloads/country_hsproduct2digit_year.tab", sep="\t")
# Out:
# C:\Users\home\.conda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# df
# Out:
#         location_id  product_id  year  export_value   import_value    hs_eci  \
# 0                 0         100  1995  20344.829346   72950.748535 -0.468138
# 1                 0         100  1996      0.000000   85945.580811 -0.663710
# 2                 0         100  1997      0.000000   30682.241211 -1.194294
# 3                 0         100  1998      0.000000    5127.259277  0.199708
# 4                 0         100  1999  16095.740479  188272.045654 -0.083034
# ...             ...         ...   ...           ...            ...       ...
# 557513          238         404  2014      0.000000       0.000000       NaN
# 557514          238         404  2015      0.000000       0.000000       NaN
# 557515          238         404  2016      0.000000       0.000000       NaN
# 557516          238         404  2017      0.000000       0.000000       NaN
# 557517          238         404  2018      0.000000       0.000000       NaN
#
# ...

# %%
# df.to_csv("C:/Users/home/Documents/Monu-Hw [KD]/project_2/country_hsproduct2digit_year.csv", index=False)

# %%
df = pd.read_csv("c:/users/home/documents/data-viz-project/data/country_hsproduct2digit_year.csv")
# Out:
# C:\Users\home\.conda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
country_counts = df.location_code.unique()

# %%
country_counts
# Out:
# array(['ABW', 'AFG', 'AGO', 'AIA', 'ALB', 'AND', 'ANT', 'ARE', 'ARG',
#        'ARM', 'ATF', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN',
#        'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU',
#        'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'CAF', 'CAN', 'CCK', 'CHE',
#        'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COK', 'COL', 'COM',
#        'CPV', 'CRI', 'CUB', 'CXR', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI',
#        'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESH', 'ESP',
#        'EST', 'ETH', 'FIN', 'FJI', 'FLK', 'FRA', 'FRO', 'FSM', 'GAB',
#        'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GLP', 'GMB', 'GNB', 'GNQ',
#        'GRC', 'GRD', 'GRL', 'GTM', 'GUF', 'GUY', 'HKG', 'HND', 'HRV',
#        'HTI', 'HUN', 'IDN', 'IND', 'IOT', 'IRL', 'IRN', 'IRQ', 'ISL',
#        'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM',
#        'KIR', 'KNA', 'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA',
# ...

# %%
country_counts.shape
# Out:
# (243,)

# %%
df.year
# Out:
# 0         1995
# 1         1996
# 2         1997
# 3         1998
# 4         1999
#           ...
# 557513    2014
# 557514    2015
# 557515    2016
# 557516    2017
# 557517    2018
# Name: year, Length: 557518, dtype: int64

# %%
export_val_by_cty_year = df.groupby(['location_code','year']).sum().reset_index()
export_val_by_cty_year.head(30)
# Out:
#    location_code  year  location_id  product_id  export_value  import_value  \
# 0            ABW  1995            0       16366  1.256915e+09  1.668601e+09
# 1            ABW  1996            0       16366  1.500080e+09  2.495330e+09
# 2            ABW  1997            0       16366  1.731203e+09  2.635874e+09
# 3            ABW  1998            0       16366  1.496785e+09  1.944622e+09
# 4            ABW  1999            0       16366  1.793451e+09  1.295614e+09
# 5            ABW  2000            0       16366  3.282020e+09  1.403386e+09
# 6            ABW  2001            0       16366  3.016251e+09  1.188610e+09
# 7            ABW  2002            0       16366  2.149598e+09  1.513882e+09
# 8            ABW  2003            0       16366  2.718532e+09  1.908143e+09
# 9            ABW  2004            0       16366  3.473500e+09  2.437373e+09
# 10           ABW  2005            0       16366  4.877568e+09  3.690534e+09
# ...

# %%
export_val_by_cty_prodId = df.groupby(['location_code','product_id']).sum().reset_index()
export_val_by_cty_prodId
# Out:
#       location_code  product_id  location_id   year  export_value  \
# 0               ABW         100            0  48156  1.741611e+06
# 1               ABW         101            0  48156  8.004310e+06
# 2               ABW         102            0  48156  1.402919e+07
# 3               ABW         103            0  48156  7.556783e+06
# 4               ABW         104            0  48156  1.610565e+05
# ...             ...         ...          ...    ...           ...
# 24494           ZWE         400         5952  48156  0.000000e+00
# 24495           ZWE         401         5952  48156  1.397948e+09
# 24496           ZWE         402         5952  48156  8.289652e+08
# 24497           ZWE         403         5952  48156  9.099418e+08
# 24498           ZWE         404         5952  48156  0.000000e+00
#
#        import_value     hs_eci     hs_coi        pci
# 0      1.618188e+07   4.915503 -12.708102 -13.859391
# 1      5.352267e+08   4.915503 -12.708102  -3.043823
# ...

# %%
export_val_by_cty = df.groupby('location_code').sum().reset_index()
export_val_by_cty
# Out:
#     location_code  location_id  product_id     year  export_value  \
# 0             ABW            0      392784  4911912  6.763467e+10
# 1             AFG         2448      392784  4911912  2.420610e+10
# 2             AGO         4896      392784  4911912  6.823695e+11
# 3             AIA         6984      344544  4671132  2.359791e+08
# 4             ALB         9792      392784  4911912  6.729241e+10
# ..            ...          ...         ...      ...           ...
# 238           WSM       592416      392784  4911912  4.346163e+09
# 239           YEM       594864      392784  4911912  1.123242e+11
# 240           ZAF       602208      392784  4911912  1.906264e+12
# 241           ZMB       604656      392784  4911912  9.998047e+10
# 242           ZWE       607104      392784  4911912  5.340169e+10
#
#      import_value       hs_eci       hs_coi         pci
# 0    5.952923e+10   501.381317 -1296.226405 -620.140306
# 1    1.447627e+11 -1358.944940 -1569.827357 -620.140306
# ...

# %%
# loading country code csv file
country_df = pd.read_csv('c:/users/home/documents/data-viz-project/data/wikipedia-iso-country-codes.csv')
country_df.head(5)
# Out:
#   English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                      Zimbabwe           ZW          ZWE           716
# 1                        Zambia           ZM          ZMB           894
# 2                         Yemen           YE          YEM           887
# 3                Western Sahara           EH          ESH           732
# 4             Wallis and Futuna           WF          WLF           876
#
#       ISO 3166-2
# 0  ISO 3166-2:ZW
# 1  ISO 3166-2:ZM
# 2  ISO 3166-2:YE
# 3  ISO 3166-2:EH
# 4  ISO 3166-2:WF

# %%
country_df = country_df.rename(columns={'Alpha-3 code': 'location_code','English short name lower case':'country_name'})

# %%
country_df
# Out:
#           country_name Alpha-2 code location_code  Numeric code     ISO 3166-2
# 0             Zimbabwe           ZW           ZWE           716  ISO 3166-2:ZW
# 1               Zambia           ZM           ZMB           894  ISO 3166-2:ZM
# 2                Yemen           YE           YEM           887  ISO 3166-2:YE
# 3       Western Sahara           EH           ESH           732  ISO 3166-2:EH
# 4    Wallis and Futuna           WF           WLF           876  ISO 3166-2:WF
# ..                 ...          ...           ...           ...            ...
# 241     American Samoa           AS           ASM            16  ISO 3166-2:AS
# 242            Algeria           DZ           DZA            12  ISO 3166-2:DZ
# 243            Albania           AL           ALB             8  ISO 3166-2:AL
# 244        Afghanistan           AF           AFG             4  ISO 3166-2:AF
# 245      Åland Islands           AX           ALA           248  ISO 3166-2:AX
#
# [246 rows x 5 columns]

# %%
country_df.drop(columns = ['Alpha-2 code','Numeric code', 'ISO 3166-2'], inplace = True)
country_df
# Out:
#           country_name location_code
# 0             Zimbabwe           ZWE
# 1               Zambia           ZMB
# 2                Yemen           YEM
# 3       Western Sahara           ESH
# 4    Wallis and Futuna           WLF
# ..                 ...           ...
# 241     American Samoa           ASM
# 242            Algeria           DZA
# 243            Albania           ALB
# 244        Afghanistan           AFG
# 245      Åland Islands           ALA
#
# [246 rows x 2 columns]

# %%
country_df
# Out:
#           country_name Alpha-2 code location_code  Numeric code     ISO 3166-2
# 0             Zimbabwe           ZW           ZWE           716  ISO 3166-2:ZW
# 1               Zambia           ZM           ZMB           894  ISO 3166-2:ZM
# 2                Yemen           YE           YEM           887  ISO 3166-2:YE
# 3       Western Sahara           EH           ESH           732  ISO 3166-2:EH
# 4    Wallis and Futuna           WF           WLF           876  ISO 3166-2:WF
# ..                 ...          ...           ...           ...            ...
# 241     American Samoa           AS           ASM            16  ISO 3166-2:AS
# 242            Algeria           DZ           DZA            12  ISO 3166-2:DZ
# 243            Albania           AL           ALB             8  ISO 3166-2:AL
# 244        Afghanistan           AF           AFG             4  ISO 3166-2:AF
# 245      Åland Islands           AX           ALA           248  ISO 3166-2:AX
#
# [246 rows x 5 columns]

# %%
df = df.merge(country_df, on='location_code')

# %%
# Out:
#      location_id  product_id  year  export_value  import_value    hs_eci  \
# 0              0         100  1995  20344.829346  7.295075e+04 -0.468138
# 1              0         100  1996      0.000000  8.594558e+04 -0.663710
# 2              0         100  1997      0.000000  3.068224e+04 -1.194294
# 3              0         100  1998      0.000000  5.127259e+03  0.199708
# 4              0         100  1999  16095.740479  1.882720e+05 -0.083034
# ..           ...         ...   ...           ...           ...       ...
# 145            0         106  1996   7941.731079  7.956828e+05 -0.663710
# 146            0         106  1997   1447.705933  1.336789e+06 -1.194294
# 147            0         106  1998      0.000000  2.047286e+06  0.199708
# 148            0         106  1999   2655.712891  1.810023e+06 -0.083034
# 149            0         106  2000   5836.271118  1.335405e+06  0.349085
#
#        hs_coi       pci location_code hs_product_code country_name
# ...

# %%
df.to_csv("c:/users/home/documents/data-viz-project/data/countries_data.csv", index=False)
