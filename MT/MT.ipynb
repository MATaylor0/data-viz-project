# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Data/country_hsproduct2digit_year.csv", low_memory = False)
df
# Out:
#         location_id  product_id  year  export_value   import_value    hs_eci  \
# 0                 0         100  1995  20344.829346   72950.748535 -0.468138
# 1                 0         100  1996      0.000000   85945.580811 -0.663710
# 2                 0         100  1997      0.000000   30682.241211 -1.194294
# 3                 0         100  1998      0.000000    5127.259277  0.199708
# 4                 0         100  1999  16095.740479  188272.045654 -0.083034
# ...             ...         ...   ...           ...            ...       ...
# 557513          238         404  2014      0.000000       0.000000       NaN
# 557514          238         404  2015      0.000000       0.000000       NaN
# 557515          238         404  2016      0.000000       0.000000       NaN
# 557516          238         404  2017      0.000000       0.000000       NaN
# 557517          238         404  2018      0.000000       0.000000       NaN
#
# ...

# %%
export_val_by_year = df.groupby(["location_code", "year"]).sum().reset_index()
export_val_by_year.head()
# Out:
#   location_code  year  location_id  product_id  export_value  import_value  \
# 0           ABW  1995            0       16366  1.256915e+09  1.668601e+09
# 1           ABW  1996            0       16366  1.500080e+09  2.495330e+09
# 2           ABW  1997            0       16366  1.731203e+09  2.635874e+09
# 3           ABW  1998            0       16366  1.496785e+09  1.944622e+09
# 4           ABW  1999            0       16366  1.793451e+09  1.295614e+09
#
#        hs_eci     hs_coi        pci
# 0  -47.750089 -71.054941 -28.008040
# 1  -67.698426 -71.854512 -29.856209
# 2 -121.818019 -83.537149 -29.508802
# 3   20.370240 -71.889620 -28.908602
# 4   -8.469503 -81.719406 -27.795010

# %%
export_val_2018 = export_val_by_year.loc[export_val_by_year["year"] == 2018]

# %%
export_val_2018
# Out:
#      location_code  year  location_id  product_id  export_value  import_value  \
# 23             ABW  2018            0       16366  2.128368e+08  1.508728e+09
# 47             AFG  2018          102       16366  1.189541e+09  9.601058e+09
# 71             AGO  2018          204       16366  4.252746e+10  2.118759e+10
# 95             AIA  2018          291       14356  1.210860e+07  1.344755e+08
# 119            ALB  2018          408       16366  6.449804e+09  7.962410e+09
# ...            ...   ...          ...         ...           ...           ...
# 5486           WSM  2018        24684       16366  4.771567e+07  4.064172e+08
# 5510           YEM  2018        24786       16366  1.402799e+09  8.717321e+09
# 5534           ZAF  2018        25092       16366  1.230489e+11  1.053711e+11
# 5558           ZMB  2018        25194       16366  9.301761e+09  8.934505e+09
# 5582           ZWE  2018        25296       16366  2.194002e+09  4.088859e+09
#
# ...

# %%
# Country ISO codes
iso_df = pd.read_csv("../Data/wikipedia-iso-country-codes.csv")
iso_df
# Out:
#     English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                        Zimbabwe           ZW          ZWE           716
# 1                          Zambia           ZM          ZMB           894
# 2                           Yemen           YE          YEM           887
# 3                  Western Sahara           EH          ESH           732
# 4               Wallis and Futuna           WF          WLF           876
# ..                            ...          ...          ...           ...
# 241                American Samoa           AS          ASM            16
# 242                       Algeria           DZ          DZA            12
# 243                       Albania           AL          ALB             8
# 244                   Afghanistan           AF          AFG             4
# 245                 Åland Islands           AX          ALA           248
#
#         ISO 3166-2
# 0    ISO 3166-2:ZW
# 1    ISO 3166-2:ZM
# ...

# %%
iso_df = iso_df.rename(columns = {"Alpha-3 code": "location_code", "English short name lower case": "country_name"})
iso_df
# Out:
#           country_name Alpha-2 code location_code  Numeric code     ISO 3166-2
# 0             Zimbabwe           ZW           ZWE           716  ISO 3166-2:ZW
# 1               Zambia           ZM           ZMB           894  ISO 3166-2:ZM
# 2                Yemen           YE           YEM           887  ISO 3166-2:YE
# 3       Western Sahara           EH           ESH           732  ISO 3166-2:EH
# 4    Wallis and Futuna           WF           WLF           876  ISO 3166-2:WF
# ..                 ...          ...           ...           ...            ...
# 241     American Samoa           AS           ASM            16  ISO 3166-2:AS
# 242            Algeria           DZ           DZA            12  ISO 3166-2:DZ
# 243            Albania           AL           ALB             8  ISO 3166-2:AL
# 244        Afghanistan           AF           AFG             4  ISO 3166-2:AF
# 245      Åland Islands           AX           ALA           248  ISO 3166-2:AX
#
# [246 rows x 5 columns]

# %%
iso_df = iso_df[["location_code", "country_name"]]
iso_df
# Out:
#     location_code       country_name
# 0             ZWE           Zimbabwe
# 1             ZMB             Zambia
# 2             YEM              Yemen
# 3             ESH     Western Sahara
# 4             WLF  Wallis and Futuna
# ..            ...                ...
# 241           ASM     American Samoa
# 242           DZA            Algeria
# 243           ALB            Albania
# 244           AFG        Afghanistan
# 245           ALA      Åland Islands
#
# [246 rows x 2 columns]

# %%
merged_df = export_val_2018.merge(iso_df, on = "location_code")
merged_df
# Out:
#     location_code  year  location_id  product_id  export_value  import_value  \
# 0             ABW  2018            0       16366  2.128368e+08  1.508728e+09
# 1             AFG  2018          102       16366  1.189541e+09  9.601058e+09
# 2             AGO  2018          204       16366  4.252746e+10  2.118759e+10
# 3             AIA  2018          291       14356  1.210860e+07  1.344755e+08
# 4             ALB  2018          408       16366  6.449804e+09  7.962410e+09
# ..            ...   ...          ...         ...           ...           ...
# 226           WSM  2018        24684       16366  4.771567e+07  4.064172e+08
# 227           YEM  2018        24786       16366  1.402799e+09  8.717321e+09
# 228           ZAF  2018        25092       16366  1.230489e+11  1.053711e+11
# 229           ZMB  2018        25194       16366  9.301761e+09  8.934505e+09
# 230           ZWE  2018        25296       16366  2.194002e+09  4.088859e+09
#
# ...

# %%
merged_df.to_csv("static/data/export_data_2018.csv", index = False)
