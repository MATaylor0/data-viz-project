# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_stata("../Data/country_hsproduct2digit_year.dta")
df.loc[df["location_code"] == "ABW", :]
# Out:
#         location_id  product_id  year  export_value  import_value    hs_eci  \
# 0                 0         100  1995  2.034483e+04  7.295075e+04 -0.468138
# 1                 0         100  1996  0.000000e+00  8.594558e+04 -0.663710
# 2                 0         100  1997  0.000000e+00  3.068224e+04 -1.194294
# 3                 0         100  1998  0.000000e+00  5.127259e+03  0.199708
# 4                 0         100  1999  1.609574e+04  1.882720e+05 -0.083034
# ...             ...         ...   ...           ...           ...       ...
# 552617            0         404  2014  1.361381e+07  2.943232e+07  0.817055
# 552618            0         404  2015  1.769838e+07  3.558256e+07  0.786367
# 552619            0         404  2016  1.685398e+07  3.177764e+07  0.937783
# 552620            0         404  2017  0.000000e+00  0.000000e+00  0.855724
# 552621            0         404  2018  0.000000e+00  0.000000e+00  0.916250
#
#           hs_coi       pci location_code hs_product_code
# ...

# %%
df
# Out:
#         location_id  product_id  year  export_value   import_value    hs_eci  \
# 0                 0         100  1995  20344.829346   72950.748535 -0.468138
# 1                 0         100  1996      0.000000   85945.580811 -0.663710
# 2                 0         100  1997      0.000000   30682.241211 -1.194294
# 3                 0         100  1998      0.000000    5127.259277  0.199708
# 4                 0         100  1999  16095.740479  188272.045654 -0.083034
# ...             ...         ...   ...           ...            ...       ...
# 557513          238         404  2014      0.000000       0.000000       NaN
# 557514          238         404  2015      0.000000       0.000000       NaN
# 557515          238         404  2016      0.000000       0.000000       NaN
# 557516          238         404  2017      0.000000       0.000000       NaN
# 557517          238         404  2018      0.000000       0.000000       NaN
#
# ...
